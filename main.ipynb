# %% [markdown]
# # converting signals into images, bin files (.npz)
# # このノートブックの目的は、機械学習用データセットを生成することです。大きく4つのパートに分かれています。
# # - シミュレーションデータ変換　(.mat → .npz)
# # - シミュレーションデータセット作成　(.npz + config.json → x_train.npy, t_train.npy)
# # - 実機データ変換　(.mat → .npz)
# # - 実機データセット作成　(.npz → x_train_real.npy, t_train_real.npy)
# # これらをInputとして深層モデルを訓練してください。

# %% [markdown]
# ### 初期セットアップ
# パスの関係を以下に定義します。前提として、シミュレーションで生成した大量のデータは保管されし、それをdl_workspaceに移しているものとします。

# %%
import os
import yaml
import numpy as np

with open("config/config.yaml", 'r', encoding='utf-8') as f:
    config = yaml.safe_load(f)

base_dir = config['base']['base_dir']
work_dir = os.path.join(base_dir, "dl_workspace")

# Simulation
base_dir_sim = os.path.join(work_dir, "assets", "datasets", "2024", "simulation")
rawsignal_dir_sim = os.path.join(base_dir_sim, "rawsignal")
processed_dir_sim = os.path.join(base_dir_sim, "processed")
dataset_dir_sim = os.path.join(base_dir_sim, "datasets")

# Experiments
base_dir_exp = os.path.join(work_dir, "assets", "datasets", "2024", "experiments")
rawsignal_dir_exp = os.path.join(base_dir_exp, "rawsignal")
rawsignal_dir_exp_solid_liquid = os.path.join(rawsignal_dir_exp, "solid_liquid")
processed_dir_exp_all = os.path.join(base_dir_exp, "processed", "all")
dataset_dir_exp = os.path.join(base_dir_exp, "dataset")
target_csv = os.path.join(base_dir_exp, "target_variables.csv")

# Output
visualize_dir = os.path.join(work_dir, "visualize")
logs_dir = os.path.join(work_dir, "logs")
results_dir = os.path.join(work_dir, "results")

# %% [markdown]
# ## シミュレーションデータ変換
#  シミュレーションで生成した`.mat`のファイルを統一形式である`.npz`に変換します。以下は、フォルダを指定するとその配下のファイルをすべて一括で変換し、`/processed`ディレクトリに保存するという処理を行うものです。

# %%
from src import batch_convert_sim

case_dirs = sorted([
    d for d in os.listdir(rawsignal_dir_sim)
    if os.path.isdir(os.path.join(rawsignal_dir_sim, d))
])
print(f"Found {len(case_dirs)} cases: {case_dirs}")

for case_name in case_dirs:
    print(f"\n--- Processing {case_name} ---")
    batch_convert_sim(case_name, base_dir_sim)
# Out:
# Found 25 cases: ['case1', 'case10', 'case12', 'case14', 'case16', 'case17', 'case18', 'case19', 'case2', 'case20', 'case22', 'case23_noattenuation', 'case24', 'case26', 'case27', 'case28', 'case3', 'case30', 'case4', 'case5', 'case6', 'case7', 'case8', 'case9', 'sample']
#
# --- Processing case1 ---
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case1/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case1/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case1/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case1/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case1/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case1/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case1/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case1/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case1/solid_liquid_reflector10_processed.npz
#
# --- Processing case10 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case10/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case10/solid_liquid_reflector7_processed.npz
#
# --- Processing case12 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case12/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case12/solid_liquid_reflector7_processed.npz
#
# --- Processing case14 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case14/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case14/solid_liquid_reflector7_processed.npz
#
# --- Processing case16 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case16/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case16/solid_liquid_reflector7_processed.npz
#
# --- Processing case17 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case17/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case17/solid_liquid_reflector7_processed.npz
#
# --- Processing case18 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case18/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case18/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# ...
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case8/solid_liquid_reflector7_processed.npz
#
# --- Processing case9 ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector3_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/case9/data/solid_liquid_reflector7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/case9/solid_liquid_reflector7_processed.npz
#
# --- Processing sample ---
# Created output directory: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample
# Copied config.json to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/config.json
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid4.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid4_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid7.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid7_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid6.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid6_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid8.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid8_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid2_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid1_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid10_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid9.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid9_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid5.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid5_processed.npz
# Processing: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/rawsignal/sample/data/solid_liquid3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /mnt/matsubara/dl_workspace/assets/datasets/2024/simulation/processed/sample/solid_liquid3_processed.npz

# %% [markdown]
# ## 機械学習用データセット生成（シミュレーション）
# 　次に、変換した`.npz`のファイルに対応する目標変数となる値を`/config.json`を使って計算し、データセットとなる`x_train.npy`,`t_train.npy`を作成していきます。これらのiDの紐づけが狂うとすべての計算の意味がなくなってしまうので、最大限注意してください。
# また、実機への展開をスムーズにするために、最大値を用いてスケーリングしていることに注意して下さい。その他順序付けなど筆者は細心の注意を払って実装していますが、もし誤りがあればご指摘いただけると幸いです。

# %%
from src import npz2png,process_case_and_return_dataset



x_list = []
t_list = []

# Get all case directories (e.g., case5, case6, ...)
case_dirs = sorted([d for d in os.listdir(processed_dir_sim) if os.path.isdir(os.path.join(processed_dir_sim, d)) and d.startswith("case")])

x_train_list = []
t_train_list = []

for case_name in case_dirs:
    base_dir = os.path.join(processed_dir_sim, case_name)
    print(f"Processing {case_name} in {base_dir}")
    x_tmp, t_tmp = process_case_and_return_dataset(case_name, base_dir)
    print(f"x_tmp shape: {x_tmp.shape}, t_tmp shape: {t_tmp.shape}")
    x_train_list.append(x_tmp)
    t_train_list.append(t_tmp)
print("list done")
# Concatenate all cases into single arrays
x_train = np.concatenate(x_train_list, axis=0)
t_train = np.concatenate(t_train_list, axis=0)
x_train = x_train/np.max(x_train)
x_train = np.log1p(x_train)
# x_train = x_train/np.max(x_train)
print("Final x_train shape:", x_train.shape)
print("Final t_train shape:", t_train.shape)
print(np.max(x_train),np.min(x_train))
np.save(os.path.join(dataset_dir_sim, "x_train.npy"), x_train)
np.save(os.path.join(dataset_dir_sim, "t_train.npy"), t_train)
#print(np.max(x_train))
#print(t_train)
#print(x_train)
npz_file_path = os.path.join(processed_dir_sim, "case5/solid_liquid4_processed.npz")
output_folder_path = results_dir
os.makedirs(output_folder_path, exist_ok=True)
npz2png(npz_file_path, output_folder_path, channel_index=0, start_time=0.0, end_time=None, full=True, pulse_index=0)
npz2png(npz_file_path, output_folder_path, channel_index=0, start_time=0.0, end_time=None, full=False, pulse_index=0)

# %% [markdown]
# ## チェック
# ケース毎の固相体積率を計算するコードです。

# %%
from src import calculate_gvf_and_signal
import yaml
import os

# Load configuration from YAML file
with open("config/config.yaml", 'r', encoding='utf-8') as f:
    config = yaml.safe_load(f)

config_path = os.path.join(processed_dir_sim, "case5/config.json")
npz_path = os.path.join(processed_dir_sim, "case4/solid_liquid4_processed.npz")
input_tmp, target_tmp = calculate_gvf_and_signal(config_path, npz_path)
print(input_tmp.shape,target_tmp)
# Out:
# (2500,) 0.028535685586967636

# %% [markdown]
# ## 実機データ変換
# 実機データの`.mat`のファイルも、先ほどと同様に統一形式である`.npz`に変換します。同じく、`experiments/processed`に保存されるようにしています。下のものは、サンプルを一つだけ変換するものです。

# %%
from src import mat2npz_exp, npz2png

file_name = "P20241007-1419.mat"
file_path = os.path.join(rawsignal_dir_exp_solid_liquid, file_name)

mat2npz_exp(
        file_path=file_path,
        output_dir=processed_dir_exp_all,
        start_time=0.1,  #初期の信号は不安定であることが多いため除外
        duration=5.0,
        amplitude_threshold=2,
        window_width=0.1e-3,
        signal_key="TDX1"
    )
npz2png(
    file_path=os.path.join(processed_dir_exp_all, "P20240726-1601_processed.npz"),
    save_path=processed_dir_exp_all,
    full=False,
    pulse_index=0,
    channel_index=1
)

# %% [markdown]
# ## 複数を一括で変換するスクリプト

# %%
from src import mat2npz_exp,npz2png
import os
import glob
import yaml

# Load configuration from YAML file
with open("config/config.yaml", 'r', encoding='utf-8') as f:
    config = yaml.safe_load(f)

# Get all .mat files in the rawsignal directory

mat_files = glob.glob(os.path.join(rawsignal_dir_exp_solid_liquid, "*.mat"))


for file_path in mat_files:
    print(f"Processing {file_path}")
    mat2npz_exp(
        file_path=file_path,
        output_dir=processed_dir_exp_all,
        start_time=0.1,  #初期の信号は不安定であることが多いため除外
        duration=5.0,
        amplitude_threshold=2,
        window_width=0.1e-3,
        signal_key="TDX1"
    )

# %% [markdown]
# ## 機械学習用データセット生成(実機)
# 次に、変換した`.npz`のファイルに対応する目標変数となる値を`/target_variables.csv`を使って参照し、データセット`x_test.npy` `t_test.npy`を作成していきます。
# なお、ここではただ入力と出力のペアを作成しただけであり、外れ値除去などは実装していません。それらは、機械学習用レポジトリ`https://github.com/apetrasc/ml_airlift`に記載します。

# %%
import polars as pl
from scipy.signal import resample_poly
df = pl.read_csv(target_csv, encoding="shift_jis")


# "ガラス球直径"列の右隣に、"P2024{日付}{時分}_processed.npz"という名前列を追加
# コピーを作成し、result_dirに保存

# まず既存のdfをコピー
df_copy = df.clone()

# 新しいカラム名
new_col_name = "ファイル名"

# "P2024" + 日付 + 時分 + "_processed.npz"を作成
df_copy = df_copy.with_columns(
    (pl.lit("P") + df_copy["日付"].cast(pl.Utf8) + "-" + df_copy["時分"].cast(pl.Utf8) + "_processed.npz").alias(new_col_name)
)

# "ガラス球直径"列のすぐ右隣りに挿入
glass_col_idx = df_copy.columns.index("ガラス球直径")
cols = df_copy.columns.copy()
cols.insert(glass_col_idx + 1, cols.pop(-1))  # 新しいカラム(最後にある)を目的位置へ

df_final = df_copy.select(cols)

# 保存
os.makedirs(logs_dir, exist_ok=True)
save_path = os.path.join(logs_dir, "target_variables_with_filename.csv")
df_final.write_csv(save_path)

print(f"saved: {save_path}")

# 再読込（または前の df_final を使用）
df_work = df_final.clone()

# "FullPath" を作成
fullpath_col = "FullPath"
df_work = df_work.with_columns(
    (pl.lit(processed_dir_exp_all.rstrip("/") + "/") + df_work["ファイル名"]).alias(fullpath_col)
)

# "ガラス球直径" のインデックス取得し、2つ右隣に "FullPath" を移動
glass_idx = df_work.columns.index("ガラス球直径")
# "ファイル名"は1つ右、その隣=2つ右になるよう "FullPath" を移動
cols = df_work.columns.copy()
# 一旦 "FullPath" をpop
cols.pop(cols.index(fullpath_col))
cols.insert(glass_idx + 2, fullpath_col)
df_final2 = df_work.select(cols)

# 保存
save_path2 = os.path.join(logs_dir, "target_variables_with_fullpath.csv")
df_final2.write_csv(save_path2)
print(f"saved: {save_path2}")

df_final2.head()



df = pl.read_csv(os.path.join(logs_dir, 'target_variables_with_fullpath.csv'), encoding='utf-8')
print(f"CSV rows: {len(df)}")

# CSVファイルの行数だけ処理する
file_paths = df_final2["FullPath"].to_list()
print(f"Total CSV rows to process: {len(file_paths)}")

processed_data_list = []
targets_list = []
processed_dir_exp = os.path.join(base_dir_exp, "processed")

for i, p in enumerate(file_paths):
    # ファイルの存在確認
    if not os.path.exists(p):
        print(f"[SKIP {i+1}/{len(file_paths)}] File not found: {p}")
        # 両方のリストにNoneを追加して同期を保つ
        processed_data_list.append(None)
        targets_list.append(None)
        continue
    
    # パスが正しいディレクトリ内にあるか確認
    if not p.startswith(processed_dir_exp):
        print(f"[SKIP {i+1}/{len(file_paths)}] Path not in expected directory: {p}")
        processed_data_list.append(None)
        targets_list.append(None)
        continue
    
    try:
        data_npz = np.load(p)
    except Exception as e:
        print(f"[ERROR {i+1}/{len(file_paths)}] Failed to load: {p} ({e})")
        processed_data_list.append(None)
        targets_list.append(None)
        continue

    if 'processed_data' not in data_npz:
        print(f"[SKIP {i+1}/{len(file_paths)}] 'processed_data' key not found in: {p}")
        processed_data_list.append(None)
        targets_list.append(None)
        continue

    arr = data_npz['processed_data']
    print(f"[{i+1}/{len(file_paths)}] {p}: original shape: {arr.shape}")
    
    # arrは(14000, 2500, 4)のshapeになっている想定
    # 14000 (時間) を 1/10 の 1400 にダウンサンプリングしたい（時間軸はaxis=0）
    target_length = 1400
    original_length = arr.shape[0]
    up = target_length
    down = original_length

    if arr.shape[0] != target_length:
        # arr の shape: (T, W, C) -> 軸入れ替えず、そのまま axis=0 でダウンサンプリング
        # 例えば (14000, 2500, 4) → (1400, 2500, 4)
        arr_ds = resample_poly(arr, up, down, axis=0)
        print(f"    downsampled shape: {arr_ds.shape}")
        arr = arr_ds
    else:
        print("    no downsampling necessary.")

    # 軸が (T, W, C)=(1400, 2500, 4) なので (C, T, W)に変形
    if arr.ndim == 3:
        arr_T = np.transpose(arr, (2, 0, 1))
        print(f"    transposed shape: {arr_T.shape}")
        
        # ターゲット変数を先に取得（エラーが発生した場合に備えて）
        try:
            row = df_final2.row(i)
            targets = np.array([
                float(row[df_final2.columns.index("固相見かけ流速")]),
                float(row[df_final2.columns.index("気相見かけ流速")]),
                float(row[df_final2.columns.index("液相見かけ流速")]),
                float(row[df_final2.columns.index("固相体積率")]),
                float(row[df_final2.columns.index("気相体積率")]),
                float(row[df_final2.columns.index("液相体積率")])
            ])
            # 両方のリストに同時に追加（同期を保つ）
            processed_data_list.append(arr_T)
            targets_list.append(targets)
        except Exception as e:
            print(f"    [ERROR] Failed to load targets for row {i}: {e}")
            # エラー時も両方にNoneを追加して同期を保つ
            processed_data_list.append(None)
            targets_list.append(None)
            continue
    else:
        print(f"    [SKIP] processed_data is not 3D (got shape {arr.shape}), skipping")
        processed_data_list.append(None)
        targets_list.append(None)

# Noneを取り除き、対応するインデックスで処理（同期を保つ）
valid_indices = [i for i, data in enumerate(processed_data_list) if data is not None]
processed_data_valids = [processed_data_list[i] for i in valid_indices]
targets_valids = [targets_list[i] for i in valid_indices]

print(f"\n[SUMMARY]")
print(f"Total CSV rows: {len(file_paths)}")
print(f"Successfully processed: {len(processed_data_valids)}")
print(f"Failed/Skipped: {len(file_paths) - len(processed_data_valids)}")
print(f"processed_data_list length: {len(processed_data_list)}")
print(f"targets_list length: {len(targets_list)}")
print(f"Valid data count: {len(processed_data_valids)}")
print(f"Valid targets count: {len(targets_valids)}")

if len(processed_data_valids) == 0:
    print("No valid data could be loaded. combined_data will be None")
    combined_data = None
else:
    combined_data = np.stack(processed_data_valids, axis=0)
    print(f"Final shape: {combined_data.shape}")

x_train_real = combined_data
t_train_real = np.stack(targets_valids, axis=0)

print(f"\nx_train_real shape: {x_train_real.shape}")
print(f"t_train_real shape: {t_train_real.shape}")

# 形状の一致を確認
if x_train_real.shape[0] != t_train_real.shape[0]:
    print(f"\n[WARNING] Shape mismatch detected!")
    print(f"  x_train_real samples: {x_train_real.shape[0]}")
    print(f"  t_train_real samples: {t_train_real.shape[0]}")
    print(f"  Difference: {x_train_real.shape[0] - t_train_real.shape[0]}")
else:
    print(f"\n[OK] Shapes match: {x_train_real.shape[0]} samples")
# Out:
# saved: /mnt/matsubara/dl_workspace/logs/target_variables_with_filename.csv
# saved: /mnt/matsubara/dl_workspace/logs/target_variables_with_fullpath.csv
# CSV rows: 359
# Total CSV rows to process: 359
# [SKIP 1/359] File not found: /mnt/matsubara/dl_workspace/assets/datasets/2024/experiments/processed/all/P20