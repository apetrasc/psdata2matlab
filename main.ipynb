# %% [markdown]
# # converting signals into images, bin files(.npz)
#
# このノートブックではディレクトリを指定して、その中にある生波形データ(.mat)を、一括して画像(.png)及びその値（.npz）に変換し保存するという処理を行っています。

# %% [markdown]
# ## シミュレーションデータ変換
#  シミュレーションで生成した`.mat`のファイルを統一形式である`.npz`に変換します。以下は、フォルダを指定するとその配下のファイルをすべて一括で変換し、`/processed`ディレクトリに保存するという処理を行うものです。

# %%
from src import mat2npz_sim,npz2png
import os
import glob

# Define input and output directories
# Define the case name as a variable for clarity and reusability
case_name = "case1"

# Define base data directory for clarity
base_data_dir = "/home/smatsubara/documents/airlift/data/simulation"
visualize_dir = "/home/smatsubara/documents/airlift/data/visualize"
def convert_all_simulation_mat_to_npz(case_name, base_data_dir):
    """
    Convert all simulation .mat files in the specified case directory to .npz format.

    Parameters
    ----------
    case_name : str
        The name of the simulation case (e.g., "case5").
    base_data_dir : str
        The base directory where simulation data is stored.
    """
    # Define input directory for raw simulation signals (relative to base_data_dir and case_name)
    mat_dir = os.path.join(base_data_dir, f"rawsignal/{case_name}/data")

    # Define config file path (relative to base_data_dir and case_name)
    config_path = os.path.join(base_data_dir, f"rawsignal/{case_name}/config.json")

    # Define output directory for processed files (relative to base_data_dir and case_name)
    output_dir = os.path.join(base_data_dir, f"processed/{case_name}")
    # Create the output directory if it does not exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")
    # Save a copy of the config.json file to the output directory for reference
    import shutil
    config_copy_path = os.path.join(output_dir, "config.json")
    shutil.copy2(config_path, config_copy_path)
    print(f"Copied config.json to: {config_copy_path}")

    # Create the output directory if it does not exist
    os.makedirs(output_dir, exist_ok=True)
    mat_files_list = glob.glob(os.path.join(mat_dir, "*.mat"))
    for mat_file in mat_files_list:
        print(f"Processing: {mat_file}")
        mat2npz_sim(mat_file, config_path, output_dir)

# 関数の呼び出し例
convert_all_simulation_mat_to_npz(case_name, base_data_dir)

npz2png(file_path="/home/smatsubara/documents/airlift/data/simulation/processed/case26/solid_liquid_reflector3_processed.npz",save_path=visualize_dir,full=False,pulse_index=0)
npz2png(file_path="/home/smatsubara/documents/airlift/data/simulation/processed/case9/solid_liquid_reflector3_processed.npz",save_path=visualize_dir,full=True,pulse_index=0)
# Out:
# Copied config.json to: /home/smatsubara/documents/airlift/data/simulation/processed/case1/config.json
# Processing: /home/smatsubara/documents/airlift/data/simulation/rawsignal/case1/data/solid_liquid_reflector1.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /home/smatsubara/documents/airlift/data/simulation/processed/case1/solid_liquid_reflector1_processed.npz
# Processing: /home/smatsubara/documents/airlift/data/simulation/rawsignal/case1/data/solid_liquid_reflector10.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /home/smatsubara/documents/airlift/data/simulation/processed/case1/solid_liquid_reflector10_processed.npz
# Processing: /home/smatsubara/documents/airlift/data/simulation/rawsignal/case1/data/solid_liquid_reflector2.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /home/smatsubara/documents/airlift/data/simulation/processed/case1/solid_liquid_reflector2_processed.npz
# Processing: /home/smatsubara/documents/airlift/data/simulation/rawsignal/case1/data/solid_liquid_reflector3.mat
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']>
# ['Nt', 'Nx', 'Ny', 'Nz', 'dim', 'dt', 'dx', 'dxudxn', 'dxudxn_sgx', 'dy', 'dyudyn', 'dyudyn_sgy', 'dz', 'dzudzn', 'dzudzn_sgz', 'k', 'k_max', 'kx_max', 'kx_vec', 'ky_max', 'ky_vec', 'kz_max', 'kz_vec', 'nonuniform', 'xn_vec', 'xn_vec_sgx', 'yn_vec', 'yn_vec_sgy', 'zn_vec', 'zn_vec_sgz']
# 999999999.9999999
# keys: ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# ['#refs#', '#subsystem#', 'kgrid', 'sensor_data']
# (50000,)
# Processed data and metadata saved to: /home/smatsubara/documents/airlift/data/simulation/processed/case1/solid_liquid_reflector3_processed.npz
# /home/smatsubara/documents/airlift/data/visualize/solid_liquid_reflector3_processed_0pulse0.png
# /home/smatsubara/documents/airlift/data/visualize/solid_liquid_reflector3_processed_0img0.png

# %% [markdown]
# ## 機械学習用データセット生成（シミュレーション）
# 　次に、変換した`.npz`のファイルに対応する目標変数となる値を`/config.json`を使って計算し、データセットとなる`x_train.npy`,`t_train.npy`を作成していきます。これらのiDの紐づけが狂うとすべての計算の意味がなくなってしまうので、最大限注意してください。
# また、実機への展開をスムーズにするために、最大値を用いてスケーリングしていることに注意して下さい。その他順序付けなど筆者は細心の注意を払って実装していますが、もし誤りがあればご指摘いただけると幸いです。

# %%
from src import calculate_gvf_and_signal,npz2png,process_case_and_return_dataset
import numpy as np
import math
import json
import glob
import os
#units are all mm

x_list = []
t_list = []

# Define the base directory containing all cases
processed_base_dir = "/home/smatsubara/documents/airlift/data/simulation/processed"
output_path = "/home/smatsubara/documents/airlift/data/simulation/dataset"
rawsignal_base_dir = "/home/smatsubara/documents/airlift/data/simulation/rawsignal"

# Get all case directories (e.g., case5, case6, ...)
case_dirs = sorted([d for d in os.listdir(processed_base_dir) if os.path.isdir(os.path.join(processed_base_dir, d)) and d.startswith("case")])

x_train_list = []
t_train_list = []

for case_name in case_dirs:
    base_dir = os.path.join(processed_base_dir, case_name)
    csv_dir = os.path.join(rawsignal_base_dir, case_name)
    print(f"Processing {case_name} in {base_dir}")
    x_tmp, t_tmp = process_case_and_return_dataset(case_name, base_dir, csv_dir)
    print(f"x_tmp shape: {x_tmp.shape}, t_tmp shape: {t_tmp.shape}")
    x_train_list.append(x_tmp)
    t_train_list.append(t_tmp)
print("list done")
# Concatenate all cases into single arrays
x_train = np.concatenate(x_train_list, axis=0)
t_train = np.concatenate(t_train_list, axis=0)
x_train = x_train/np.max(x_train)
x_train = np.log1p(x_train)
# x_train = x_train/np.max(x_train)
print("Final x_train shape:", x_train.shape)
print("Final t_train shape:", t_train.shape)
print(np.max(x_train),np.min(x_train))
np.save(os.path.join(output_path, "x_train.npy"), x_train)
np.save(os.path.join(output_path, "t_train.npy"), t_train)
#print(np.max(x_train))
#print(t_train)
#print(x_train)
npz_file_path = "/home/smatsubara/documents/airlift/data/simulation/processed/case5/solid_liquid4_processed.npz"
output_folder_path = "/home/smatsubara/documents/airlift/data/results/"
npz2png(npz_file_path, output_folder_path, channel_index=0, start_time=0.0, end_time=None, full=True, pulse_index=0)
npz2png(npz_file_path, output_folder_path, channel_index=0, start_time=0.0, end_time=None, full=False, pulse_index=0)

# %%
from src import calculate_gvf_and_signal

config_path = "/home/smatsubara/documents/airlift/data/simulation/processed/case30/config.json"
npz_path = "/home/smatsubara/documents/airlift/data/simulation/processed/case4/solid_liquid4_processed.npz"
input_tmp, target_tmp = calculate_gvf_and_signal(config_path, npz_path)
print(input_tmp.shape,target_tmp)

# %% [markdown]
# ## 実機データ変換
# 実機データの`.mat`のファイルも、先ほどと同様に統一形式である`.npz`に変換します。同じく、`experiments/processed`に保存されるようにしています。下のものは、サンプルを一つだけ変換するものです。

# %%
from src import mat2npz_exp,npz2png
import os
import glob
file_path = "/home/smatsubara/documents/airlift/data/experiments/rawsignal/signal_exp/20241017-1057.mat"
output_dir =  "/home/smatsubara/documents/airlift/data/experiments/processed/all"
mat2npz_exp(
        file_path=file_path,
        output_dir=output_dir,
        start_time=0.1,  #初期の信号は不安定であることが多いため除外
        duration=5.0,
        amplitude_threshold=2,
        window_width=0.1e-3,
        signal_key="TDX1"
    )
npz2png(file_path="/home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1601_processed.npz",save_path=output_dir,full=False,pulse_index=0,channel_index=1)
# Out:
# Loading data...
# Loading successful
# Using device: cuda:1
# Number of detected triggers: (14700,)
# Warning: arranged_pulses contains inf values. Replacing infs with 0.
# arranged_pulses.shape: (14700, 5208, 4)
# convert_exp finished
# max: inf
# processed_data.shape: (14000, 2500, 4)
# max: inf
# Warning: processed_data contains inf values. Replacing infs with 0.
# processed_data[0,:,0].shape: (2500,)
# max: 1.1506849527359009
# argmax: 334
# maxes argmax: 3,max: 3.4028234663852886e+38
# (14000, 1, 4) 0.04892368 3.4028235e+38
# scaled: ((14000, 2500, 4), -3.4028235e+38, 3.4028235e+38)
# max_value: 3.4028234663852886e+38
# ['__header__', '__version__', '__globals__', 'Tstart', 'Tinterval', 'ExtraSamples', 'RequestedLength', 'Length', 'Version', 'TDX1', 'TDX2', 'TDX3', 'TDX1_enlarged']
# signal points: (2500,)
# Processed data and metadata saved to: /home/smatsubara/documents/airlift/data/experiments/processed/all/20241017-1057_processed.npz
# /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1601_processed_1pulse0.png

# %% [markdown]
# ## 複数を一括で変換するスクリプト

# %%
from src import mat2npz_exp,npz2png
import os

import glob

# Get all .mat files in the rawsignal directory
output_dir = "/home/smatsubara/documents/airlift/data/experiments/processed/all"
rawsignal_dir = "/home/smatsubara/documents/airlift/data/experiments/rawsignal/signal_exp"
mat_files = glob.glob(os.path.join(rawsignal_dir, "*.mat"))


for file_path in mat_files:
    print(f"Processing {file_path}")
    mat2npz_exp(
        file_path=file_path,
        output_dir=output_dir,
        start_time=0.1,  #初期の信号は不安定であることが多いため除外
        duration=5.0,
        amplitude_threshold=2,
        window_width=0.1e-3,
        signal_key="TDX1"
    )

# %% [markdown]
# ## 機械学習用データセット生成(実機)
# 次に、変換した`.npz`のファイルに対応する目標変数となる値を`/target_variables.csv`を使って参照し、データセット`x_test.npy` `t_test.npy`を作成していきます。

# %%
import polars as pl

df =pl.read_csv("/home/smatsubara/documents/airlift/data/sandbox/experiments/target_valiables.csv",encoding="shift_jis")


data_path = "/home/smatsubara/documents/airlift/data/experiments/processed/all"
# "ガラス球直径"列の右隣に、"P2024{日付}{時分}_processed.npz"という名前列を追加
# コピーを作成し、result_dirに保存

# まず既存のdfをコピー
df_copy = df.clone()

# 新しいカラム名
new_col_name = "ファイル名"

# "P2024" + 日付 + 時分 + "_processed.npz"を作成
df_copy = df_copy.with_columns(
    (pl.lit("P") + df_copy["日付"].cast(pl.Utf8) + "-" + df_copy["時分"].cast(pl.Utf8) + "_processed.npz").alias(new_col_name)
)

# "ガラス球直径"列のすぐ右隣りに挿入
glass_col_idx = df_copy.columns.index("ガラス球直径")
cols = df_copy.columns.copy()
cols.insert(glass_col_idx + 1, cols.pop(-1))  # 新しいカラム(最後にある)を目的位置へ

df_final = df_copy.select(cols)

# 保存
result_dir = "/home/smatsubara/documents/airlift/data/sandbox/results" 
save_path = result_dir.rstrip("/") + "/target_valiables_with_filename.csv"
df_final.write_csv(save_path)

print(f"saved: {save_path}")
# "ファイル名" の右隣に data_path と結合したフルパス列 "FullPath" を追加

# 再読込（または前の df_final を使用）
df_work = df_final.clone()

# "FullPath" を作成
fullpath_col = "FullPath"
df_work = df_work.with_columns(
    (pl.lit(data_path.rstrip("/") + "/") + df_work["ファイル名"]).alias(fullpath_col)
)

# "ガラス球直径" のインデックス取得し、2つ右隣に "FullPath" を移動
glass_idx = df_work.columns.index("ガラス球直径")
# "ファイル名"は1つ右、その隣=2つ右になるよう "FullPath" を移動
cols = df_work.columns.copy()
# 一旦 "FullPath" をpop
cols.pop(cols.index(fullpath_col))
cols.insert(glass_idx + 2, fullpath_col)
df_final2 = df_work.select(cols)

# 保存
save_path2 = result_dir.rstrip("/") + "/target_valiables_with_fullpath.csv"
df_final2.write_csv(save_path2)
print(f"saved: {save_path2}")

df_final2.head()
# Out:
# saved: /home/smatsubara/documents/airlift/data/sandbox/results/target_valiables_with_filename.csv
# saved: /home/smatsubara/documents/airlift/data/sandbox/results/target_valiables_with_fullpath.csv
# shape: (5, 11)
# ┌──────────┬──────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ 日付     ┆ 時分 ┆ 固相見かけ ┆ 気相見かけ ┆ … ┆ 液相体積率 ┆ ガラス球直 ┆ ファイル名 ┆ FullPath  │
# │ ---      ┆ ---  ┆ 流速       ┆ 流速       ┆   ┆ ---        ┆ 径         ┆ ---        ┆ ---       │
# │ i64      ┆ i64  ┆ ---        ┆ ---        ┆   ┆ f64        ┆ ---        ┆ str        ┆ str       │
# │          ┆      ┆ f64        ┆ f64        ┆   ┆            ┆ str        ┆            ┆           │
# ╞══════════╪══════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 20240726 ┆ 1022 ┆ 0.0        ┆ 31.922755  ┆ … ┆ 0.250842   ┆ -          ┆ P20240726- ┆ /home/sma │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ 1022_proce ┆ tsubara/d │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ ssed.npz   ┆ ocuments/ │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆            ┆ air…      │
# │ 20240726 ┆ 1055 ┆ 0.0        ┆ 32.685636  ┆ … ┆ 0.254479   ┆ -          ┆ P20240726- ┆ /home/sma │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ 1055_proce ┆ tsubara/d │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ ssed.npz   ┆ ocuments/ │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆            ┆ air…      │
# │ 20240726 ┆ 1113 ┆ 0.0        ┆ 32.048131  ┆ … ┆ 0.2453868  ┆ -          ┆ P20240726- ┆ /home/sma │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ 1113_proce ┆ tsubara/d │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ ssed.npz   ┆ ocuments/ │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆            ┆ air…      │
# │ 20240726 ┆ 1122 ┆ 0.0        ┆ 31.968982  ┆ … ┆ 0.257206   ┆ -          ┆ P20240726- ┆ /home/sma │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ 1122_proce ┆ tsubara/d │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ ssed.npz   ┆ ocuments/ │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆            ┆ air…      │
# │ 20240726 ┆ 1334 ┆ 0.0        ┆ 32.881976  ┆ … ┆ 0.25266    ┆ -          ┆ P20240726- ┆ /home/sma │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ 1334_proce ┆ tsubara/d │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆ ssed.npz   ┆ ocuments/ │
# │          ┆      ┆            ┆            ┆   ┆            ┆            ┆            ┆ air…      │
# └──────────┴──────┴────────────┴────────────┴───┴────────────┴────────────┴────────────┴───────────┘

# %%
# 1. CSVファイルの行数を確認
import polars as pl
df = pl.read_csv('/home/smatsubara/documents/airlift/data/sandbox/results/target_valiables_with_fullpath.csv', encoding='utf-8')
print(f"CSV rows: {len(df)}")

# 2. 各npzファイルのサンプル数を確認
import numpy as np
sample_counts = []
for path in df['FullPath'].to_list():
    try:
        data = np.load(path)
        if 'processed_data' in data:
            arr = data['processed_data']
            # 最初の次元がサンプル数
            if arr.ndim == 3:
                sample_counts.append(arr.shape[0])
            else:
                sample_counts.append(1)
        else:
            sample_counts.append(0)
    except:
        sample_counts.append(0)

print(f"Total samples from npz files: {sum(sample_counts)}")
print(f"Average samples per file: {sum(sample_counts) / len(sample_counts):.2f}")
# Out:
# CSV rows: 359
# Total samples from npz files: 4270000
# Average samples per file: 11894.15

# %%
import numpy as np
import os
from scipy.signal import resample_poly

# CSVファイルの行数だけ処理する
file_paths = df_final2["FullPath"].to_list()
print(f"Total CSV rows to process: {len(file_paths)}")

processed_data_list = []
targets_list = []
processed_base_dir = "/home/smatsubara/documents/airlift/data/experiments/processed/all"

for i, p in enumerate(file_paths):
    # ファイルの存在確認
    if not os.path.exists(p):
        print(f"[SKIP {i+1}/{len(file_paths)}] File not found: {p}")
        # 両方のリストにNoneを追加して同期を保つ
        processed_data_list.append(None)
        targets_list.append(None)
        continue
    
    # パスが正しいディレクトリ内にあるか確認
    if not p.startswith(processed_base_dir):
        print(f"[SKIP {i+1}/{len(file_paths)}] Path not in expected directory: {p}")
        processed_data_list.append(None)
        targets_list.append(None)
        continue
    
    try:
        data_npz = np.load(p)
    except Exception as e:
        print(f"[ERROR {i+1}/{len(file_paths)}] Failed to load: {p} ({e})")
        processed_data_list.append(None)
        targets_list.append(None)
        continue

    if 'processed_data' not in data_npz:
        print(f"[SKIP {i+1}/{len(file_paths)}] 'processed_data' key not found in: {p}")
        processed_data_list.append(None)
        targets_list.append(None)
        continue

    arr = data_npz['processed_data']
    print(f"[{i+1}/{len(file_paths)}] {p}: original shape: {arr.shape}")
    
    # arrは(14000, 2500, 4)のshapeになっている想定
    # 14000 (時間) を 1/10 の 1400 にダウンサンプリングしたい（時間軸はaxis=0）
    target_length = 1400
    original_length = arr.shape[0]
    up = target_length
    down = original_length

    if arr.shape[0] != target_length:
        # arr の shape: (T, W, C) -> 軸入れ替えず、そのまま axis=0 でダウンサンプリング
        # 例えば (14000, 2500, 4) → (1400, 2500, 4)
        arr_ds = resample_poly(arr, up, down, axis=0)
        print(f"    downsampled shape: {arr_ds.shape}")
        arr = arr_ds
    else:
        print("    no downsampling necessary.")

    # 軸が (T, W, C)=(1400, 2500, 4) なので (C, T, W)に変形
    if arr.ndim == 3:
        arr_T = np.transpose(arr, (2, 0, 1))
        print(f"    transposed shape: {arr_T.shape}")
        
        # ターゲット変数を先に取得（エラーが発生した場合に備えて）
        try:
            row = df_final2.row(i)
            targets = np.array([
                float(row[df_final2.columns.index("固相見かけ流速")]),
                float(row[df_final2.columns.index("気相見かけ流速")]),
                float(row[df_final2.columns.index("液相見かけ流速")]),
                float(row[df_final2.columns.index("固相体積率")]),
                float(row[df_final2.columns.index("気相体積率")]),
                float(row[df_final2.columns.index("液相体積率")])
            ])
            # 両方のリストに同時に追加（同期を保つ）
            processed_data_list.append(arr_T)
            targets_list.append(targets)
        except Exception as e:
            print(f"    [ERROR] Failed to load targets for row {i}: {e}")
            # エラー時も両方にNoneを追加して同期を保つ
            processed_data_list.append(None)
            targets_list.append(None)
            continue
    else:
        print(f"    [SKIP] processed_data is not 3D (got shape {arr.shape}), skipping")
        processed_data_list.append(None)
        targets_list.append(None)

# Noneを取り除き、対応するインデックスで処理（同期を保つ）
valid_indices = [i for i, data in enumerate(processed_data_list) if data is not None]
processed_data_valids = [processed_data_list[i] for i in valid_indices]
targets_valids = [targets_list[i] for i in valid_indices]

print(f"\n[SUMMARY]")
print(f"Total CSV rows: {len(file_paths)}")
print(f"Successfully processed: {len(processed_data_valids)}")
print(f"Failed/Skipped: {len(file_paths) - len(processed_data_valids)}")
print(f"processed_data_list length: {len(processed_data_list)}")
print(f"targets_list length: {len(targets_list)}")
print(f"Valid data count: {len(processed_data_valids)}")
print(f"Valid targets count: {len(targets_valids)}")

if len(processed_data_valids) == 0:
    print("No valid data could be loaded. combined_data will be None")
    combined_data = None
else:
    combined_data = np.stack(processed_data_valids, axis=0)
    print(f"Final shape: {combined_data.shape}")

x_train_real = combined_data
t_train_real = np.stack(targets_valids, axis=0)

print(f"\nx_train_real shape: {x_train_real.shape}")
print(f"t_train_real shape: {t_train_real.shape}")

# 形状の一致を確認
if x_train_real.shape[0] != t_train_real.shape[0]:
    print(f"\n[WARNING] Shape mismatch detected!")
    print(f"  x_train_real samples: {x_train_real.shape[0]}")
    print(f"  t_train_real samples: {t_train_real.shape[0]}")
    print(f"  Difference: {x_train_real.shape[0] - t_train_real.shape[0]}")
else:
    print(f"\n[OK] Shapes match: {x_train_real.shape[0]} samples")
# Out:
# Total CSV rows to process: 359
# [SKIP 1/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1022_processed.npz
# [SKIP 2/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1055_processed.npz
# [SKIP 3/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1113_processed.npz
# [SKIP 4/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1122_processed.npz
# [SKIP 5/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1334_processed.npz
# [SKIP 6/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1400_processed.npz
# [7/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1600_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [8/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1601_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [9/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1606_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [10/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1607_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [11/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1614_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [12/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240726-1615_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [13/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240729-1437_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 14/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240729-1605_processed.npz
# [15/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240729-1351_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [16/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240729-1423_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [17/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240730-1018_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [18/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240730-1052_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [19/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240730-1100_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [20/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240730-1606_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [21/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240730-1616_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 22/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240731-1028_processed.npz
# [SKIP 23/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240731-1036_processed.npz
# [24/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240805-1113_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [25/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240805-1128_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [26/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240805-1424_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [27/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240805-1013_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [28/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240805-1030_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [29/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240806-1430_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [30/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240806-1543_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [31/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240806-1601_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [32/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240806-1443_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [33/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240808-1459_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [34/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240808-1437_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [35/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1054_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [36/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1122_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [37/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1110_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [38/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1425_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [39/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1444_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [40/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1435_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [41/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1532_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [42/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1539_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [43/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1545_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [44/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1611_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [45/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1617_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [46/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1622_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [47/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1133_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [48/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240820-1414_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [49/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1002_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [50/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1018_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [51/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1029_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [52/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1039_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 53/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1605_processed.npz
# [SKIP 54/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1616_processed.npz
# [SKIP 55/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240821-1626_processed.npz
# [56/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1621_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [57/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1354_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [58/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1609_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [59/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1415_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [60/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1405_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [61/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1543_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [62/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1554_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [63/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1044_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [64/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1113_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [65/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1528_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [66/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1124_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [67/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1443_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [68/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240822-1100_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [69/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1350_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [70/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1026_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [71/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1044_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [72/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1055_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [73/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1106_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [74/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1328_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [75/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1339_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [76/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1400_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [77/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1414_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [78/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1446_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [79/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240826-1424_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [80/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1620_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [81/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1610_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [82/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1000_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 83/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1014_processed.npz
# [SKIP 84/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1027_processed.npz
# [SKIP 85/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1037_processed.npz
# [86/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1050_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [87/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1101_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [88/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1114_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [89/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1552_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [90/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1541_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [91/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1529_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [92/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240827-1125_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [93/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1040_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [94/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1013_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [95/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1024_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [96/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1051_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [97/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1104_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [98/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1115_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [99/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1329_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [100/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1348_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [101/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1401_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [102/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1414_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [103/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1427_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [104/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1445_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [105/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240828-1000_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [106/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1557_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [107/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1547_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [108/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1525_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [109/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1451_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [110/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1440_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [111/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1335_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [112/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1323_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [113/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240829-1347_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [114/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1006_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [115/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1033_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [116/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1043_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [117/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1055_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [118/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1108_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [119/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1119_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [120/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1537_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [121/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1547_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [122/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240830-1558_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [123/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240902-1557_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [124/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240902-1620_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [125/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240902-1543_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [126/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1606_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [127/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1120_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [128/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1325_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [129/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1334_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [130/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1343_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [131/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1415_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [132/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1426_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [133/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1435_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [134/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1021_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [135/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1616_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [136/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1626_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [137/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1108_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [138/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1056_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [139/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240903-1010_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [140/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240904-1058_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [141/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240904-1049_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [142/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240904-1118_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [143/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240904-1108_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [144/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1034_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [145/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1046_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [146/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1442_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [147/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1452_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [148/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1528_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [149/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1538_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [150/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240905-1550_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [151/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1526_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [152/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1536_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [153/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1515_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [154/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1044_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [155/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1001_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [156/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1012_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [157/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1023_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [158/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240906-1033_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [159/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1340_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [160/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1328_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [161/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1116_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [162/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1107_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [163/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1003_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [164/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1046_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [165/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1035_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [166/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1025_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [167/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1057_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [168/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240909-1015_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [169/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1016_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [170/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1056_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [171/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1318_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [172/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1343_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [173/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1426_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [174/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1437_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [175/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240910-1449_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [176/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1624_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [177/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1612_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [178/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1602_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [179/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1054_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [180/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1408_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [181/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1355_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [182/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1123_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [183/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1043_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [184/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240911-1420_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [185/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1115_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [186/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1055_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [187/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1035_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [188/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1025_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [189/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1015_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [190/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240917-1044_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [191/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1437_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [192/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1449_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [193/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1554_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [194/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1604_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [195/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1411_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [196/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240918-1426_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [197/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1527_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [198/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1538_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [199/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1601_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [200/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1341_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [201/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1347_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [202/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1352_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [203/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1359_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [204/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1416_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [205/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240919-1550_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [206/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1542_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [207/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1346_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [208/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1358_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [209/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1439_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [210/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1449_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [211/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1531_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [212/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240920-1600_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [213/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240925-1113_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [214/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240925-1124_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [215/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240925-1052_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [216/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240925-1104_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [217/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1600_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [218/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1106_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [219/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1332_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [220/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1349_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [221/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1419_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [222/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1432_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [223/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1546_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [224/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20240926-1614_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [225/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241002-1425_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [226/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241002-1414_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [227/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241002-1612_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [228/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241002-1620_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [229/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241002-1602_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
# ...
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [272/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1606_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [273/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1556_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [274/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1546_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [275/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1534_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [276/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1517_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [277/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1132_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [278/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1123_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [279/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1106_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [280/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1057_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [281/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1115_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 282/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-955_processed.npz
# [283/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1005_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [284/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1023_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [285/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1031_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [286/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1040_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [287/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1048_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [288/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241011-1015_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [289/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1341_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [290/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1332_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [291/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1324_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [292/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1123_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [293/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1115_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [294/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1055_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [295/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1046_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [296/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1037_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [297/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1021_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [298/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1013_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [299/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1000_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [300/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1104_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [301/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1029_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [302/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1349_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [303/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241015-1358_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [304/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1041_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [305/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1616_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [306/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1608_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [307/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1559_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [308/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1549_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [309/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1539_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [310/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1528_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [311/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1450_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [312/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1030_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [313/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1429_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [314/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1419_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [315/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1358_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [316/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1344_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [317/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1334_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [318/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1117_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [319/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1438_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [320/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241016-1057_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 321/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1619_processed.npz
# [SKIP 322/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1609_processed.npz
# [SKIP 323/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1600_processed.npz
# [SKIP 324/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1543_processed.npz
# [SKIP 325/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1535_processed.npz
# [SKIP 326/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1526_processed.npz
# [SKIP 327/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1357_processed.npz
# [SKIP 328/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1552_processed.npz
# [SKIP 329/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1330_processed.npz
# [SKIP 330/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1340_processed.npz
# [SKIP 331/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-951_processed.npz
# [332/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1003_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [333/359] /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1012_processed.npz: original shape: (14000, 2500, 4)
#     downsampled shape: (1400, 2500, 4)
#     transposed shape: (4, 1400, 2500)
# [SKIP 334/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1349_processed.npz
# [SKIP 335/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1039_processed.npz
# [SKIP 336/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1047_processed.npz
# [SKIP 337/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1057_processed.npz
# [SKIP 338/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1108_processed.npz
# [SKIP 339/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241017-1030_processed.npz
# [SKIP 340/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1619_processed.npz
# [SKIP 341/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1612_processed.npz
# [SKIP 342/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1603_processed.npz
# [SKIP 343/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1554_processed.npz
# [SKIP 344/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1546_processed.npz
# [SKIP 345/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1538_processed.npz
# [SKIP 346/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1530_processed.npz
# [SKIP 347/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1440_processed.npz
# [SKIP 348/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1433_processed.npz
# [SKIP 349/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1425_processed.npz
# [SKIP 350/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1404_processed.npz
# [SKIP 351/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1353_processed.npz
# [SKIP 352/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1343_processed.npz
# [SKIP 353/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1332_processed.npz
# [SKIP 354/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1522_processed.npz
# [SKIP 355/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241018-1413_processed.npz
# [SKIP 356/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241021-1016_processed.npz
# [SKIP 357/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241021-1000_processed.npz
# [SKIP 358/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241021-1008_processed.npz
# [SKIP 359/359] File not found: /home/smatsubara/documents/airlift/data/experiments/processed/all/P20241021-951_processed.npz
#
# [SUMMARY]
# Total CSV rows: 359
# Successfully processed: 305
# Failed/Skipped: 54
# processed_data_list length: 359
# targets_list length: 359
# Valid data count: 305
# Valid targets count: 305
# Final shape: (305, 4, 1400, 2500)
#
# x_train_real shape: (305, 4, 1400, 2500)
# t_train_real shape: (305, 6)
#
# [OK] Shapes match: 305 samples

# %%
np.save("/home/smatsubara/documents/airlift/data/sandbox/results/x_train_real.npy", x_train_real)
np.save ("/home/smatsubara/documents/airlift/data/sandbox/results/t_train_real.npy", t_train_real)

x=np.load("/home/smatsubara/documents/airlift/data/sandbox/results/x_train_real.npy")
t=np.load("/home/smatsubara/documents/airlift/data/sandbox/results/t_train_real.npy")

x.shape
t.shape
# Out:
# (305, 6)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
x=np.load("/home/smatsubara/documents/airlift/data/sandbox/results/x_train_real.npy")
t=np.load("/home/smatsubara/documents/airlift/data/sandbox/results/t_train_real.npy")

print(x.shape)
print(t.shape)
# Out:
# (305, 4, 1400, 2500)
# (305, 6)

# %%
import numpy as np
x = np.load("/home/smatsubara/documents/airlift/data/cleaned/x_train_dropped.npy")
t = np.load("/home/smatsubara/documents/airlift/data/sandbox/results/t_train_real.npy")

print(x.shape)
print(t.shape)
# Out:
# (305, 2, 1400, 2500)
# (305, 6)

# %%
x_single = x[:,:1,:,:]
print(x_single.shape)

np.save("/home/smatsubara/documents/airlift/data/cleaned/x_train_single.npy",x_single)
# Out:
# (305, 1, 1400, 2500)
